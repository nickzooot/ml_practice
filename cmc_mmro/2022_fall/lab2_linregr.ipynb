# %% [markdown]
# # Машинное обучение, ВМК МГУ
#
# ## Практическое задание 2. Exploratory Data Analysis и линейная регрессия
#
# ### Общая информация
# Дата выдачи: 08.10.2022
#
# Мягкий дедлайн: 23:59MSK 22.10.2022
#
# Жесткий дедлайн: 23:59MSK 29.10.2022

# %% [markdown]
# ### О задании
# В этом задании мы попытаемся научиться анализировать данные и выделять из них полезные признаки. Мы также будем использовать `seaborn` и научимся `sklearn`, а заодно привыкнем к основным понятиям машинного обучения.
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — **12 баллов + 4.8 бонусов**. Проверяющий имеет право снизить оценку за неэффективную реализацию или неопрятные графики.
#
# **Обратите внимание**, что в каждом разделе домашнего задания есть оцениваниемые задачи и есть вопросы. Вопросы дополняют задачи и направлены на то, чтобы проинтерпретировать или обосновать происходящее. Код без интерпретации не имеет смысла, поэтому отвечать на вопросы обязательно — за отсутствие ответов мы будем снижать баллы за задачи. Если вы ответите на вопросы, но не напишете корректный код к соответствующим оцениваемым задачам, то баллы за такое выставлены не будут.
#
# Сдавать задание после указанного срока сдачи нельзя. При выставлении неполного балла за задание в связи с наличием ошибок на усмотрение проверяющего предусмотрена возможность исправить работу на указанных в ответном письме условиях.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов. Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# <p style="color:#de3815;font-size:25px;">
# Напоминание об оформлении и выполнении ноутбука
# </p>
#
# * Все строчки должны быть выполнены. Нужно, чтобы output команды можно было увидеть, не запуская ячейки (кроме редких случаев, когда необходимо намеренно скрыть ненужный output, про такие случаи желательно писать пояснения в тексте). **В противном случае -1 балл**
# * При оформлении ДЗ нужно пользоваться данным файлом в качестве шаблона. **Не нужно** удалять и видоизменять написанный код и текст, если явно не указана такая возможность. Создавать новые ячейки с кодом/текстов там, где это осмысленно и вы считаете необходимым, конечно, можно. **В противном случае -1 балл**
# * В anytask обязательно нужно прикреплять отдельно файл с расширением ipynb (не в архиве, а именно отдельно). Если необходимо отправить еще какие-то файлы, то вынесите их в отдельный архив (если файлов много) и пришлите. **В противном случае -0.5 балла**
# ---
# * Пишите, пожалуйста, выводы и ответы на вопросы в текстовых ячейках/при помощи print в коде/как результат вывода ячейки. При их отсутствии мы не можем понять, сделали ли вы задание и понимаете, что происходит, и **поэтому будем снижать баллы**
# * Если алгоритм не сказано реализовывать явно, его всегда можно импортировать из библиотеки.
# ---
# * Про графики. _Штрафы будут применяться к каждому результату команды отображения графика (plt.show() и др. аналогичные). Исключением являются графики, генерируемые функциями каких-либо сторонних библиотек, если их нельзя кастомизировать_
#
#     * должно быть название (plt.title) графика; **В противном случае &ndash; -0.05 балла**
#     * на графиках должны быть подписаны оси (plt.xlabel, plt.ylabel); **В противном случае &ndash; -0.025 балла за каждую ось**
#     * должны быть подписаны единицы измерения (если это возможно); **В противном случае &ndash; -0.025 балла за каждую ось**
#     * все названия должны быть понятны любому человеку, знакомому с терминологией, без заглядывания в код; **В противном случае &ndash; -0.05 балла**
#     * подписи тиков на осях не должны сливаться как на одной оси, так и между ними; **В противном случае &ndash; -0.025 балла за каждую ось**
#     * если изображено несколько сущностей на одном холсте (например несколько функций), то необходима поясняющая легенда (plt.legend); **В противном случае &ndash; -0.05 балла**
#     * все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном); **В противном случае &ndash; -0.05 балла**
#     * если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах);
#     * графики должны быть не супер-микро и не супер-макро по размерам, так, чтобы можно было увидеть все, что нужно.
#     * при необходимости улучшения наглядности графиков, можно пользоваться логарифмической шкалой по осям x/y.
#
# ### А также..
#
# * Для удобства поиска вопросов, на которые от вас просят ответа, мы пометили их знаком **(?)**
# * Знак **(!)** означает, что выполнение замечания необходимо для **возможности получения полного балла**
# * Даем до +0.5 баллов за выдающиеся успехи по субъективному мнению проверяющих. Этот **бонус** не апеллируется

# %% [markdown]
# В этом ноутбуке используется библиотека `folium` для визуализации карт. Она работает в google colab!

# %%
# !pip3 install folium
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import folium

m = folium.Map(location=(55.7522200, 37.6155600), zoom_start=10)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# Если вы всё сделали правильно, то выше должна открыться карта Москвы.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

sns.set(style="darkgrid")

# %% [markdown]
# ## Часть 0. Подготовка (1 балл)

# %% [markdown]
# **Задание 1 (1 балл)**.
#
# Мы будем работать с данными из соревнования [New York City Taxi Trip Duration](https://www.kaggle.com/c/nyc-taxi-trip-duration/overview), в котором нужно было предсказать длительность поездки на такси. Скачайте обучающую выборку из этого соревнования и загрузите ее:

# %%
# !pwd
# %cd /content/drive/MyDrive/Colab\ Notebooks/sklearn_practise
# Out:
# /content
# /content/drive/MyDrive/Colab Notebooks/sklearn_practise

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/sklearn_practise

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ

df = pd.read_csv('train.csv')
df
# Out:
#                 id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0        id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1        id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2        id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3        id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4        id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
# ...            ...        ...                  ...                  ...
# 1458639  id2376096          2  2016-04-08 13:31:04  2016-04-08 13:44:02
# 1458640  id1049543          1  2016-01-10 07:35:15  2016-01-10 07:46:10
# 1458641  id2304944          2  2016-04-22 06:57:41  2016-04-22 07:10:25
# 1458642  id2714485          1  2016-01-05 15:56:26  2016-01-05 16:02:39
# 1458643  id1209952          1  2016-04-05 14:44:25  2016-04-05 14:47:43
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# ...

# %% [markdown]
# **(0.1 балл)** Обратите внимание на колонки `pickup_datetime` и `dropoff_datetime`. `dropoff_datetime` был добавлена организаторами только в обучающую выборку, то есть использовать эту колонку нельзя, давайте удалим ее. В `pickup_datetime` записаны дата и время начала поездки. Чтобы с ней было удобно работать, давайте преобразуем даты в `datetime`-объекты

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
df = df.drop(['dropoff_datetime'], axis=1)
df.pickup_datetime = pd.to_datetime(df.pickup_datetime)
df.head()
# Out:
#           id  vendor_id     pickup_datetime  passenger_count  \
# 0  id2875421          2 2016-03-14 17:24:55                1
# 1  id2377394          1 2016-06-12 00:43:35                1
# 2  id3858529          2 2016-01-19 11:35:24                1
# 3  id3504673          2 2016-04-06 19:32:31                1
# 4  id2181028          2 2016-03-26 13:30:55                1
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.982155        40.767937         -73.964630         40.765602
# 1        -73.980415        40.738564         -73.999481         40.731152
# 2        -73.979027        40.763939         -74.005333         40.710087
# 3        -74.010040        40.719971         -74.012268         40.706718
# 4        -73.973053        40.793209         -73.972923         40.782520
#
#   store_and_fwd_flag  trip_duration
# 0                  N            455
# 1                  N            663
# 2                  N           2124
# ...

# %%
df.dtypes
# Out:
# id                            object
# vendor_id                      int64
# pickup_datetime       datetime64[ns]
# passenger_count                int64
# pickup_longitude             float64
# pickup_latitude              float64
# dropoff_longitude            float64
# dropoff_latitude             float64
# store_and_fwd_flag            object
# trip_duration                  int64
# dtype: object

# %% [markdown]
# **(0.2 балла)** В колонке `trip_duration` записано целевое значение, которое мы хотим предсказывать. Давайте посмотрим на распределение таргета в обучающей выборке. Для этого нарисуйте его гистограмму:

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
# %config InlineBackend.figure_format = 'svg' 
g = sns.displot(df.trip_duration.values, bins=100)
g.axes[0,0].set_xlabel('trip_duration')
None

# %% [markdown]
# **Вопрос (0.1 балл)**: **(?)**Что можно сказать о целевой переменной по гистограмме её значений?

# %% [markdown]
# **Ответ**:
# Есть выбросы (в данном случае это записи с очень большим временем поездки), которые делают 'невидимыми' другие бины(это связано с автоматическим выбором bin_width и наличием в данном случае в формуле опредления ширины бина интерквантильнго размах в числителе, который в свою очередь мал по сравнению со всем разбросом значений)

# %% [markdown]
# В соревновании в качестве метрики качества использовалось RMSLE:
# $$\text{RMSLE}(X, y, a) = \sqrt{\frac{1}{\ell}\sum_{i=1}^{\ell} \big(\log{(y_i + 1)} - \log{(a(x_i) + 1)}\big)^2}$$
#
# **Вопрос (0.1 балл)**: **(?)**Как вы думаете, почему авторы соревнования выбрали именно RMSLE, а не RMSE?

# %% [markdown]
# **Ответ:** Думаю, что это связанно с выбросами. Мы не хотим, чтобы ошибки на выбросах сильно влияли на оценку нашей модели

# %% [markdown]
# На семинаре мы рассматривали несколько моделей линейной регрессии в `sklearn`, но каждая из них оптимизировала среднеквадратичную ошибку (MSE), а не RMSLE. Давайте проделаем следующий трюк: будем предсказывать не целевую переменную, а ее *логарифм*. Обозначим $\hat{y}_i = \log{(y_i + 1)}$ — модифицированный таргет, а $\hat{a}(x_i)$ — предсказание модели, которая обучалась на $\hat{y}_i$, то есть логарифм таргета. Чтобы предсказать исходное значение, мы можем просто взять экспоненту от нашего предсказания: $a(x_i) = \exp(\hat{a}(x_i)) - 1$.
#
# **Вопрос (0.3 балла)**: **(?)**Покажите, что оптимизация RMSLE для модели $a$ эквивалентна оптимизации MSE для модели $\hat{a}$.
#
# **Доказательство**: Напишие прямо тут в ячейке, при необходимости использовав синтаксис LaTeX в ячейке
#
# ╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
#
# $$\text{RMSLE}(X, y, a) = \text{RMSE}(X, \hat{y}, \hat{a}) $$
#   $\text{RMSE}(X, \hat{y}, \hat{a})$ эквивалентно $\text{MSE}(X, \hat{y}, \hat{a})$ Отсюда и следует доказываемое утверждение

# %% [markdown]
# **(0.1 балл)** Итак, мы смогли свести задачу оптимизации RMSLE к задаче оптимизации MSE, которую мы умеем решать! Кроме того, у логарифмирования таргета есть еще одно полезное свойство. Чтобы его увидеть, добавьте к нашей выборке колонку `log_trip_duration` (воспользуйтесь `np.log1p`) и нарисуйте гистограмму модифицированного таргета по обучающей выборке. Удалите колонку со старым таргетом.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:
df['log_trip_duration'] = np.log1p(df['trip_duration'])
df = df.drop(['trip_duration'], axis=1)

# %%
sns.distplot(df.log_trip_duration)
None
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **(0.1 балл)** Чтобы иметь некоторую точку отсчета, давайте посчитаем значение метрики MSE при наилучшем константном предсказании:

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
from sklearn.metrics import mean_squared_error
best_const_prediction = np.full(df.shape[0], np.mean(df.log_trip_duration))
print("MSE in case of y_pred being the  best constant prediction: %f" % 
      mean_squared_error(df.log_trip_duration, best_const_prediction))
# Out:
# MSE in case of y_pred being the  best constant prediction: 0.633233

# %% [markdown]
# ## Часть 1. Изучаем `pickup_datetime` (4 балла)
#
# **Задание 2 (0.5 баллов)**.
#
# **(0.25 баллов)** Для начала давайте посмотрим, сколько всего было поездок в каждый из дней. Постройте график зависимости количества поездок от дня в году (например, можно воспользоваться `sns.countplot`):

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
plt.figure(figsize=(20,5))
ax = sns.countplot(x=df.pickup_datetime.dt.dayofyear)
ax.set_xlabel("Pickup day of the year",fontsize=20)
ax.set_ylabel("Counts",fontsize=20)
ax.tick_params(labelsize=5, rotation=90)

# %% [markdown]
# Вы, вероятно, заметили, что на графике есть 2 периода с аномально маленькими количествами поездок.
#
# **(0.1 балл**)Вычислите, в какие даты происходили эти скачки вниз и найдите информацию о том, что происходило в эти дни в Нью-Йорке.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
df.pickup_datetime.dt.date.value_counts()[-3:]
# Out:
# 2016-05-30    5570
# 2016-01-24    3383
# 2016-01-23    1648
# Name: pickup_datetime, dtype: int64

# %%
import datetime
days_of_year = [23, 24, 151]
year = np.datetime64('2016')
print('Strange jumps down (dates):')
for dayofyear in days_of_year:
    timedelt = np.timedelta64(dayofyear - 1, 'D')
    print(year + timedelt)
# Out:
# Strange jumps down (dates):
# 2016-01-23
# 2016-01-24
# 2016-05-30

# %% [markdown]
# В 2016-01-23, 2016-01-24 был сильный снегопад. В 2016-05-30 был день памяти военных, погибших во всех войнах

# %% [markdown]
# **(0.15 баллов)** Нарисуйте графики зависимости количества поездок от дня недели и от часов в сутках (воспользуйтесь `sns.relplot`):

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
plt.figure(figsize = (7,7))
ax = sns.relplot(x=['Mon','Tue','Wen','Thu','Fri','Sut','Sun'],
                 y=df.pickup_datetime.dt.dayofweek.value_counts().sort_index(),
                 kind='line')
ax.set_ylabels('Количество поездок', fontsize = 14)
ax.set_xlabels('День недели', fontsize = 14)
None

# %%
g = sns.relplot(x=range(24),
                 y=df.pickup_datetime.dt.hour.value_counts().sort_index(),
                 kind='line')
g.figure.set_size_inches((10, 5))
g.set_ylabels('Количество поездок', fontsize = 14)
g.set_xlabels('Час в сутках', fontsize = 14)
g.ax.set_xticks(range(24))
g.ax.set_xticklabels(labels = list(range(24)))
None

# %% [markdown]
# **Задание 3 (1 балл)**.
#
# * **(0.3 балла)** Нарисуйте на одном графике зависимости количества поездок от часа в сутках для разных месяцев (разные кривые, соответствующие разным месяцам, окрашивайте в разные цвета, воспользуйтесь `hue` в `sns.relplot`).
# * **(0.3 балла)** Аналогично нарисуйте зависимости количества поездок от часа в сутках для разных дней недели.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
df['pickup_hour'] = df.pickup_datetime.dt.hour
df['pickup_month'] = df.pickup_datetime.dt.month
df['pickup_dayofweek'] = df.pickup_datetime.dt.dayofweek

# %%
df1 = df.groupby(['pickup_month', 'pickup_hour']).size().to_frame('n_trips')
g = sns.relplot(palette='muted', data=df1, x='pickup_hour', y='n_trips', hue='pickup_month', kind='line', ci=False, legend=False)
g.figure.set_size_inches((10, 5))
g.set_ylabels('Количество поездок', fontsize = 14)
g.set_xlabels('Час в сутках', fontsize = 14)
plt.legend(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June'], title='Months', bbox_to_anchor=(1.05, 1))
g.ax.set_xticks(range(24))
g.ax.set_xticklabels(labels = list(range(24)))
None

# %%
df2 = df.groupby(['pickup_dayofweek', 'pickup_hour']).size().to_frame('n_trips')
g = sns.relplot(palette='muted', data=df2, x='pickup_hour', y='n_trips', hue='pickup_dayofweek', kind='line', ci=False, legend=False)
g.figure.set_size_inches((10, 5))
g.set_ylabels('Количество поездок', fontsize = 14)
g.set_xlabels('Час в сутках', fontsize = 14)
plt.legend(['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sut', 'Sun'], title='Day of week', bbox_to_anchor=(1.05, 1))
g.ax.set_xticks(range(24))
g.ax.set_xticklabels(labels = list(range(24)))
data = df.drop(['pickup_dayofweek', 'pickup_month', 'pickup_hour'], axis=1)
None

# %% [markdown]
# **Вопрос  (0.4 балла)**: **(?)** Какие выводы можно сделать, основываясь на графиках выше? Выделяются ли какие-нибудь дни недели? Месяца? Время суток? С чем это связано?

# %% [markdown]
# **Ответ**:
#
# ***Дни недели:***
#
# Как ни странно с субботу и в воскресенье такси пользуется популярностью больше остальных дней в это время суток(с 0 до 4-5 утра). Видимо, это связано с насыщенной ночной жизнью людей в это время. Тем не менее если смотреть на всю картину в целом, то в буднии дни куда больше поездок чем в выходные с 5 до 11 утра и с 17 до 21 вечера. Это тоже просто объяснить. В будние дни люди идут на работу утром и уходят вечером, а в выходные утром никому не охота куда-то спешить и ,по-видимому, чаще остаются дома.
#
# ***Месяц:***
#
# В месяцах в целом ничего необычного нет. Все показывают примерно одинаковые результаты. Отметим лишь, в марте, апреле, мае такси пользуется большим спросом. Возможно, это связано с плохой погодой(слякоть, дожди)
#
# ***Врем суток:***
#
# Пик с 18 до 20 часов вечера. Сильный спад в количестве с 1 до 6 утра (люди спят/сидят по домам)

# %% [markdown]
# **Задание 4 (1 балл)**.
#
# **(0.1 балл) за каждый пункт**
# * Разбейте выборку на обучающую и тестовую в отношении 7:3.
# * По обучающей выборке нарисуйте график зависимости среднего логарифма времени поездки от дня недели.
# * Затем сделайте то же самое, но для часа в сутках и дня в году.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
from sklearn.model_selection import train_test_split
y = df['log_trip_duration']
X = df.drop(['log_trip_duration'], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

# %%
g = sns.relplot(x= X_train.pickup_datetime.dt.dayofweek, 
            y=y_train,
            kind='line')
g.set_xlabels('Pickup day of week')
g.set_ylabels('Log trip duration')
g.ax.set_xticks(range(7))
g.ax.set_xticklabels(['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sut', 'Sun'])
None

# %%
g = sns.relplot(x= X_train.pickup_datetime.dt.hour, 
            y=y_train,
            kind='line')
g.figure.set_size_inches((7, 5))
g.set_xlabels('Pickup hour')
g.set_ylabels('Log trip duration')
g.ax.set_xticks(range(24))
g.ax.set_xticklabels(range(24))
None

# %%
g = sns.relplot(x=X_train.pickup_datetime.dt.dayofyear,
                y=y_train,
                kind='line', color='g')
g.figure.set_size_inches((19, 5))
g.set_xlabels('Pickup day of year')
g.ax.tick_params(axis='x', labelrotation=90, labelsize=5)
g.ax.set_xticks(range(1, 183))
g.ax.set_xticklabels(range(1, 183))
g.ax.set_xlim(0, 183)
g.set_ylabels('Log trip duration')
None

# %% [markdown]
# **Вопрос (0.3 балла)**: **(?)**Похожи ли графики зависимости таргета от дня недели и от часа в сутках на аналогичные графики для количества поездок? Почему? Что происходит со средним таргетом в те два аномальных периода, что мы видели выше? Почему так происходит? Наблюдаете ли вы какой-нибудь тренд на графике зависимости `log_trip_duration` от номера дня в году?

# %% [markdown]
# **Ответ**:
# Графики похожи. Думаю и схожесть связана с тем, что ч ростом количества машин растет количество времени поездки(Пробки создаются). В период снегопада(2016-01-23, 2016-01-24) поездки по времени были похожими в среднем на другие, но уже 25 и 26 числа поездки становятся  аномально длинными, что связанно с затрудненным движением после сильной пурги. А в 2016-05-30 был праздник и средний таргет в пределах нормы(движение, видимо, не затруднено). Есть некоторая периодичность на графике зависимости log_trip_duration от номера дня в году это объясняется тем, что в выходные дороги не столько загружены как в будни.

# %% [markdown]
# **(0.1 балл)**
# Добавьте следующие признаки на основе `pickup_datetime`:
# 1. День недели
# 2. Месяц
# 3. Час
# 4. Является ли период аномальным (два бинарных признака, соответствующие двум аномальным периодам)
# 5. Номер дня в году

# %%
 X_train.pickup_datetime.dt.month
# Out:
# 824746     3
# 645821     3
# 691846     4
# 1147931    3
# 183569     4
#           ..
# 1348317    5
# 1154171    1
# 617841     3
# 1048548    4
# 1393929    4
# Name: pickup_datetime, Length: 1021050, dtype: int64

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
X_train['dayofweek'] = X_train.pickup_datetime.dt.dayofweek
X_train['month'] = X_train.pickup_datetime.dt.month
X_train['hour'] = X_train.pickup_datetime.dt.hour
X_train['anomal1'] = (X_train.pickup_datetime.dt.dayofyear == 23) | (X_train.pickup_datetime.dt.dayofyear == 24)
X_train['anomal2'] = X_train.pickup_datetime.dt.dayofyear == 151
X_train['dayofyear'] = X_train.pickup_datetime.dt.dayofyear
X_test['dayofweek'] = X_test.pickup_datetime.dt.dayofweek
X_test['month'] = X_test.pickup_datetime.dt.month
X_test['hour'] = X_test.pickup_datetime.dt.hour
X_test['anomal1'] = (X_test.pickup_datetime.dt.dayofyear == 23) | (X_test.pickup_datetime.dt.dayofyear == 24)
X_test['anomal2'] = X_test.pickup_datetime.dt.dayofyear == 151
X_test['dayofyear'] = X_test.pickup_datetime.dt.dayofyear
X_test.head(3)
# Out:
#                id  vendor_id     pickup_datetime  passenger_count  \
# 112342  id2631171          2 2016-01-23 00:09:14                1
# 840803  id2892416          1 2016-02-10 19:24:14                3
# 184538  id3095142          2 2016-05-12 06:39:26                1
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 112342        -74.006615        40.731712         -73.991890
# 840803        -73.963203        40.777924         -74.004059
# 184538        -73.987595        40.719822         -74.010994
#
#         dropoff_latitude store_and_fwd_flag  pickup_hour  pickup_month  \
# 112342         40.727161                  N            0             1
# 840803         40.747654                  N           19             2
# 184538         40.716148                  N            6             5
#
#         pickup_dayofweek  dayofweek  month  hour  anomal1  anomal2  dayofyear
# 112342                 5          5      1     0     True    False         23
# ...

# %% [markdown]
# Итак, мы уже создали некоторое количество признаков.
#
# **Вопрос (0.3 балла)**: **(?)**Какие из признаков стоит рассматривать как категориальные, а какие - как численные? Почему?

# %% [markdown]
# **Ответ**:
# dayofyear- числовой признак. Остальные категориальные, поскольку их как это ни странно можно определить к категории(все множества день_недели, месяц, час, аномалии являются конечными и всегда определнными множествами). Я бы определил dayofyear к численному, поскольку в один и тот же год, месяц, день мы можем получить разные порядковые номера дней в году следовательно множество dayofyear может меняться и какую-то конкретную категорию выделить нельзя. Следовательно его корректнее было было бы определить как численный.

# %% [markdown]
# **Задание 5 (1.5 балла)**. Обучите `Ridge`-регрессию с параметрами по умолчанию, закодировав все категориальные признаки с помощью `OneHotEncoder`. Численные признаки отмасштабируйте с помощью `StandardScaler`. Используйте только признаки, которые мы выделили в этой части задания.

# %%
X_train.columns
# Out:
# Index(['id', 'vendor_id', 'pickup_datetime', 'passenger_count',
#        'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
#        'dropoff_latitude', 'store_and_fwd_flag', 'pickup_hour', 'pickup_month',
#        'pickup_dayofweek', 'dayofweek', 'month', 'hour', 'anomal1', 'anomal2',
#        'dayofyear'],
#       dtype='object')

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

categorical_features = ['dayofweek', 'month', 'hour', 'anomal1', 'anomal2']
numeric_features = ['dayofyear']
column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical_features),
    ('scaling', StandardScaler(), numeric_features)
])

pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge())
])

model = pipeline.fit(X_train[categorical_features + numeric_features], y_train)
y_pred = model.predict(X_test[categorical_features + numeric_features])
print("Test MSE = %.4f" % mean_squared_error(y_test, y_pred))
# Out:
# Test MSE = 0.6201

# %% [markdown]
# ## Часть 2. Изучаем координаты (3 балла)
# Мы уже очень хорошо изучили данные о времени начала поездки, давайте теперь посмотрим на информацию о координатах начала и конца поездки. Мы подготовили для вас функцию, которая на карте рисует точки начала или конца поездки. Примеры ее вызова вы найдете ниже. Обратите внимание, что в эту функцию мы передаем лишь небольшой кусочек данных, посколько иначе функция будет работать очень долго

# %%
def show_circles_on_map(data, latitude_column, longitude_column, color):
    """
    The function draws map with circles on it.
    The center of the map is the mean of coordinates passed in data.
    
    data: DataFrame that contains columns latitude_column and longitude_column
    latitude_column: string, the name of column for latitude coordinates
    longitude_column: string, the name of column for longitude coordinates
    color: string, the color of circles to be drawn
    """

    location = (data[latitude_column].mean(), data[longitude_column].mean())
    m = folium.Map(location=location)

    for _, row in data.iterrows():
        folium.Circle(
            radius=100,
            location=(row[latitude_column], row[longitude_column]),
            color=color,
            fill_color=color,
            fill=True
        ).add_to(m)

    return m

# %%
show_circles_on_map(df.sample(1000), "pickup_latitude", "pickup_longitude", "blue")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
show_circles_on_map(df.sample(1000), "dropoff_latitude", "dropoff_longitude", "blue")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# **Вопрос**: Какие две точки выделяются на карте?

# %% [markdown]
# 1. John F Kennedy International Airport
# 2. La Guardian Airport

# %% [markdown]
# **Задание 6 (0.75 балл)**.
#
# **(0.3 балла)** Как мы все прекрасно помним, $t = s / v_{\text{ср}}$, поэтому очевидно, что самым сильным признаком будет расстояние, которое необходимо проехать. Мы не можем посчитать точное расстояние, которое необходимо преодолеть такси, но мы можем его оценить, посчитав кратчайшее расстояние между точками начала и конца поездки. Чтобы корректно посчитать расстояние между двумя точками на Земле, можно использовать функцию `haversine`. Посчитайте кратчайшее расстояние для объектов и запишите его в колонку `haversine`:

# %%
# !pip install haversine
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
from haversine import haversine, Unit
X_train['haversine'] = X_train.apply(lambda rec: haversine((rec['pickup_latitude'], rec['pickup_longitude']),
                                                         (rec['dropoff_latitude'], rec['dropoff_longitude']), unit=Unit.KILOMETERS ), axis=1)
X_test['haversine'] = X_test.apply(lambda rec: haversine((rec['pickup_latitude'], rec['pickup_longitude']),
                                                         (rec['dropoff_latitude'], rec['dropoff_longitude']), unit=Unit.KILOMETERS ), axis=1)

# %%
X_test
# Out:
#                id  vendor_id     pickup_datetime  passenger_count  \
# 112342  id2631171          2 2016-01-23 00:09:14                1
# 840803  id2892416          1 2016-02-10 19:24:14                3
# 184538  id3095142          2 2016-05-12 06:39:26                1
# 512001  id3803823          2 2016-01-21 08:31:03                1
# 776055  id3155730          2 2016-01-02 13:12:33                2
# ...           ...        ...                 ...              ...
# 846197  id1951185          1 2016-01-09 23:00:55                4
# 85559   id1088375          2 2016-06-02 15:06:24                1
# 940126  id1422099          1 2016-05-02 09:51:23                1
# 643278  id2188597          2 2016-04-06 09:28:59                1
# 151807  id0184885          1 2016-03-17 16:22:00                1
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 112342        -74.006615        40.731712         -73.991890
# ...

# %% [markdown]
# **(0.25 балла)** Так как мы предсказываем логарифм времени поездки и хотим, чтобы наши признаки были линейно зависимы с этой целевой переменной, нам нужно логарифмировать расстояние: $\log t = \log s - \log{v_{\text{ср}}}$. Запишите логарифм `haversine` в отдельную колонку:

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
X_train['log_haversine'] = np.log1p(X_train['haversine']) 
X_test['log_haversine'] = np.log1p(X_test['haversine'])

# %% [markdown]
# **(0.2 балла)** Убедимся, что логарифм расстояния лучше коррелирует с нашим таргетом, чем просто расстояние:

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
correlations = X_train[['log_haversine', 'haversine']].corrwith(y_train)
plot = sns.barplot(y=correlations.index, x=correlations)
plot.figure.set_size_inches((10, 5))

# %% [markdown]
# **Задание 7 (0.75 балла)**.
#
# **(0.2 балла)** Давайте изучим среднюю скорость движения такси. Посчитайте среднюю скорость для каждого объекта обучающей выборки, разделив `haversine` на `trip_duration`, и нарисуйте гистограмму ее распределения

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
v_avg = X_train.haversine / np.expm1(y_train) * 3600
plot = sns.distplot(v_avg, bins=100)
plot.set_xlabel("Speed (km\hour)")
None
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **(0.1 балл)** Как можно видеть по гистограмме, для некоторых объектов у нас получились очень больше значения скоростей. Нарисуйте гистограмму по объектам, для которых значение скорости получилось разумным (например, можно не включать рассмотрение объекты, где скорость больше некоторой квантили):

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:
mask = (v_avg < np.quantile(v_avg, 0.9995))
plot = sns.distplot(v_avg[mask], bins=100)
plot.set_xlabel("Speed (km\hour)")
None
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **(0.1 балл)** Для каждой пары (день недели, час суток) посчитайте медиану скоростей. Нарисуйте с помощью `sns.heatmap` график, где по осям будут дни недели и часы, а в качестве значения функции - медиана скорости

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
X_train['v_avg'] = v_avg
plt.figure(figsize=(15, 5))
speed_med = X_train.groupby(['dayofweek', 'hour'])['v_avg'].median().unstack()
plot = sns.heatmap(data=speed_med, 
                   annot=True, 
                   yticklabels=['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sut', 'Sun'],
                   fmt='.1f')
X_train = X_train.drop(['v_avg'], axis=1)

# %% [markdown]
# Не забудьте удалить колонку со значением скорости из данных!
#
# **Вопрос (0.1 балл)**: **(?)** Почему значение скорости нельзя использовать во время обучения?

# %% [markdown]
# **Ответ**:
# Значение скорости нельзя использовать так как в ней неявно присутствует таргет. Модель просто переобучиться из-за утечки данных.

# %% [markdown]
# **Вопрос (0.1 балл)**: **(?)** Посмотрите внимательно на график и скажите, в какие моменты времени скорость минимальна; максимальна.

# %% [markdown]
# **Ответ**:
#
# Скорость минимала с 8:00 до 15:00.
# Скорость максимальна с 03:00 до 6:00

# %% [markdown]
# **(0.15 балл)** Создайте признаки "поездка совершается в период пробок" и "поездка совершается в период свободных дорог" (естественно, они не должен зависеть от скорости!):

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
X_train['traffic_jams'] = ((X_train.pickup_datetime.dt.hour < 15) &
                           (X_train.pickup_datetime.dt.hour > 8))
X_train['empty_roads'] = ((X_train.pickup_datetime.dt.hour < 6) &
                          (X_train.pickup_datetime.dt.hour > 3))
X_test['traffic_jams'] = ((X_test.pickup_datetime.dt.hour < 15) &
                           (X_test.pickup_datetime.dt.hour > 8))
X_test['empty_roads'] = ((X_test.pickup_datetime.dt.hour < 6) &
                          (X_test.pickup_datetime.dt.hour > 3))

# %% [markdown]
# **Задание 8 (0.25 балла)**.
#
# **(0.05 балла)** Как уже было замечено выше, на карте выделяются две точки вдали от Манхэттена. Для каждой из них добавьте в выборку два признака: началась ли поездка в ней и закончилась ли она в ней.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
coo_GuardAirport = (40.7769271, -73.87396559)
coo_KennedyAirport = (40.641766, -73.780968)

dist_from_GuardAirport_pickup = X_train.apply(lambda rec: haversine((rec['pickup_latitude'], rec['pickup_longitude']),
                                                                    coo_GuardAirport, unit=Unit.KILOMETERS ), axis=1)
dist_from_GuardAirport_dropoff = X_train.apply(lambda rec: haversine((rec['dropoff_latitude'], rec['dropoff_longitude']),
                                                                     coo_GuardAirport, unit=Unit.KILOMETERS ), axis=1)

dist_from_KennedyAirport_pickup = X_train.apply(lambda rec: haversine((rec['pickup_latitude'], rec['pickup_longitude']),
                                                                      coo_KennedyAirport, unit=Unit.KILOMETERS ), axis=1)
dist_from_KennedyAirport_dropoff = X_train.apply(lambda rec: haversine((rec['dropoff_latitude'], rec['dropoff_longitude']),
                                                                     coo_KennedyAirport, unit=Unit.KILOMETERS ), axis=1)

X_train['GuardAirport_pickup'] = dist_from_GuardAirport_pickup < 0.45
X_train['GuardAirport_dropoff'] = dist_from_GuardAirport_dropoff < 0.45
X_train['KennedyAirport_pickup'] = dist_from_GuardAirport_pickup < 0.5
X_train['KennedyAirport_dropoff'] = dist_from_GuardAirport_dropoff < 0.5
X_train.head()
# Out:
#                 id  vendor_id     pickup_datetime  passenger_count  \
# 824746   id2365163          2 2016-03-27 00:25:29                3
# 645821   id3126187          2 2016-03-18 20:44:12                1
# 691846   id2588127          2 2016-04-15 18:26:12                2
# 1147931  id0915715          2 2016-03-24 14:28:34                1
# 183569   id3758776          1 2016-04-28 13:53:52                1
#
#          pickup_longitude  pickup_latitude  dropoff_longitude  \
# 824746         -73.996986        40.742210         -73.987740
# 645821         -73.989929        40.741760         -73.977280
# 691846         -73.972366        40.750725         -73.861832
# 1147931        -73.982361        40.776901         -73.975128
# 183569         -73.973778        40.764374         -73.966957
#
#          dropoff_latitude store_and_fwd_flag  pickup_hour  ...  anomal2  \
# 824746          40.710659                  N            0  ...    False
# ...

# %%
dist_from_GuardAirport_pickup = X_test.apply(lambda rec: haversine((rec['pickup_latitude'], rec['pickup_longitude']),
                                                                    coo_GuardAirport, unit=Unit.KILOMETERS ), axis=1)
dist_from_GuardAirport_dropoff = X_test.apply(lambda rec: haversine((rec['dropoff_latitude'], rec['dropoff_longitude']),
                                                                     coo_GuardAirport, unit=Unit.KILOMETERS ), axis=1)

dist_from_KennedyAirport_pickup = X_test.apply(lambda rec: haversine((rec['pickup_latitude'], rec['pickup_longitude']),
                                                                      coo_KennedyAirport, unit=Unit.KILOMETERS ), axis=1)
dist_from_KennedyAirport_dropoff = X_test.apply(lambda rec: haversine((rec['dropoff_latitude'], rec['dropoff_longitude']),
                                                                     coo_KennedyAirport, unit=Unit.KILOMETERS ), axis=1)

X_test['GuardAirport_pickup'] = dist_from_GuardAirport_pickup < 0.45
X_test['GuardAirport_dropoff'] = dist_from_GuardAirport_dropoff < 0.45
X_test['KennedyAirport_pickup'] = dist_from_GuardAirport_pickup < 0.5
X_test['KennedyAirport_dropoff'] = dist_from_GuardAirport_dropoff < 0.5
X_test.head()
# Out:
#                id  vendor_id     pickup_datetime  passenger_count  \
# 112342  id2631171          2 2016-01-23 00:09:14                1
# 840803  id2892416          1 2016-02-10 19:24:14                3
# 184538  id3095142          2 2016-05-12 06:39:26                1
# 512001  id3803823          2 2016-01-21 08:31:03                1
# 776055  id3155730          2 2016-01-02 13:12:33                2
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 112342        -74.006615        40.731712         -73.991890
# 840803        -73.963203        40.777924         -74.004059
# 184538        -73.987595        40.719822         -74.010994
# 512001        -73.969055        40.763618         -73.974129
# 776055        -73.950165        40.775635         -73.944534
#
#         dropoff_latitude store_and_fwd_flag  pickup_hour  ...  anomal2  \
# 112342         40.727161                  N            0  ...    False
# ...

# %%
sns.displot(dist_from_GuardAirport_pickup[dist_from_GuardAirport_pickup < np.quantile(dist_from_GuardAirport_pickup, 0.015)])

# %%
sns.displot(dist_from_KennedyAirport_pickup[dist_from_KennedyAirport_pickup < np.quantile(dist_from_KennedyAirport_pickup, 0.0155)])

# %% [markdown]
# **(0.1 балл)** Для каждого из созданных признаков нарисуйте "ящик с усами" (`sns.boxplot`) распределения логарифма времени поездки

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:
plt.figure(figsize=(16, 8))

a = plt.subplot(141)
sns.boxplot(x=X_train['GuardAirport_pickup'], y=y_train)
a.set_xlabel("Picking up from  La Guardia Airport")
a.set_ylabel("Log trip duration")

a = plt.subplot(142)
sns.boxplot(x=X_train['GuardAirport_dropoff'], y=y_train)
a.set_xlabel("Dropping off in La Guardia Airport")
a.set_ylabel("Log trip duration")

a = plt.subplot(143)
sns.boxplot(x=X_train['KennedyAirport_pickup'], y=y_train)
a.set_xlabel("Picking up from  Kennedy Airport")
a.set_ylabel("Log trip duration")

a = plt.subplot(144)
sns.boxplot(x=X_train['KennedyAirport_dropoff'], y=y_train)
a.set_xlabel("Dropping off in Kennedy Airport")
a.set_ylabel("Log trip duration")
None
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# **Вопрос (0.1 балл)**: **(?)** судя по графикам, как вы думаете, хорошими ли получились эти признаки?

# %% [markdown]
# **Ответ:**
# Признаки получились хорошими, поскольку медианы значений признаков различаются. Следовательно выборки имеют разное распределение

# %% [markdown]
# <img src="https://www.dropbox.com/s/xson9nukz5hba7c/map.png?raw=1" align="right" width="20%" style="margin-left: 20px; margin-bottom: 20px">
#
# **Задание 9 (1 балл)**. Сейчас мы почти что не используем сами значения координат. На это есть несколько причин: по отдельности рассматривать широту и долготу не имеет особого смысла, стоит рассматривать их вместе. Во-вторых, понятно, что зависимость между нашим таргетом и координатами не линейная. Чтобы как-то использовать координаты, можно прибегнуть к следующему трюку: обрамим область с наибольшим количеством поездок прямоугольником (как на рисунке). Разобьем этот прямоугольник на ячейки. Каждой точке сопоставим номер ее ячейки, а тем точкам, что не попали ни в одну из ячеек, сопоставим значение -1.
#
# Напишите трансформер, который сначала разбивает показанную на рисунке область на ячейки, а затем создает два признака: номер ячейки, в которой началась поездка, и номер ячейки, в которой закончилась поездка. Количество строк и столбцов выберите самостоятельно.
#
# Обратите внимание, что все вычисления должны быть векторизованными, трансформер не должен модифицировать передаваемую ему выборку inplace, а все необходимые статистики (если они вдруг нужны) нужно считать только по обучающей выборке в методе `fit`:

# %%
X_train
# Out:
#                 id  vendor_id     pickup_datetime  passenger_count  \
# 824746   id2365163          2 2016-03-27 00:25:29                3
# 645821   id3126187          2 2016-03-18 20:44:12                1
# 691846   id2588127          2 2016-04-15 18:26:12                2
# 1147931  id0915715          2 2016-03-24 14:28:34                1
# 183569   id3758776          1 2016-04-28 13:53:52                1
# ...            ...        ...                 ...              ...
# 1348317  id2763967          1 2016-05-12 05:16:06                1
# 1154171  id0853058          1 2016-01-16 19:14:54                1
# 617841   id2242904          1 2016-03-21 20:11:12                1
# 1048548  id2558617          1 2016-04-09 09:21:44                1
# 1393929  id3799449          1 2016-04-27 09:11:19                1
#
#          pickup_longitude  pickup_latitude  dropoff_longitude  \
# 824746         -73.996986        40.742210         -73.987740
# ...

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class MapGridTransformer(BaseEstimator, TransformerMixin):
    #╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
    cols = 6
    raws = 6
    def __init__(self):
        pass
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        X_ = X.copy()
        point1 = (-74.017836, 40.702821) # left down
        point2 = (-74.017836, 40.793854) # left up
        point3 = (-73.956725, 40.793854) # right up
        point4 = (-73.956725, 40.702821) # right down 

        grid_x_width = (point3[0] - point1[0]) / self.cols
        grid_y_width = (point2[1] - point1[1]) / self.raws
        numb_col = np.floor(((point3[0] - X_['pickup_longitude']) / grid_x_width))
        
        numb_raw = np.floor(((point3[1] - X_['pickup_latitude']) / grid_y_width))

        mask = ((numb_col >= self.cols) | (numb_raw >= self.raws) |
               (numb_col < 0) | (numb_raw < 0))

        
        X_['pickup_idx'] = -1
        X_.loc[~mask, 'pickup_idx'] = (numb_col * numb_raw + numb_col)[~mask]
            
        numb_col = np.floor(((point3[0] - X_['dropoff_longitude']) / grid_x_width))
        numb_raw = np.floor(((point3[1] - X_['dropoff_latitude']) / grid_y_width))
        mask = ((numb_col >= self.cols) | (numb_raw >= self.raws) |
               (numb_col < 0) | (numb_raw < 0))
        X_['dropoff_idx'] = -1
        X_.loc[~mask, 'dropoff_idx'] = (numb_col * numb_raw + numb_col)[~mask]
        return X_

# %% [markdown]
# **Задание 10 (0.25 балла)**. Обучите `Ridge`-регрессию со стандартными параметрами на признаках, которые мы выделили к текущему моменту, закодировав категориальные признаки с помощью `OneHotEncoder`. Численные признаки отмасштабируйте с помощью `StandardScaler`.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
categorical_features = ['dayofweek', 'month', 'hour', 'anomal1',
                        'anomal2', 'traffic_jams', 'empty_roads', 
                        'GuardAirport_pickup', 'GuardAirport_dropoff',
                        'KennedyAirport_pickup', 'KennedyAirport_dropoff',
                        'pickup_idx', 'dropoff_idx']

numeric_features = ['dayofyear', 'log_haversine']

column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical_features),
    ('scaling', StandardScaler(), numeric_features)
])

pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge())
])

transformed_X_train = (MapGridTransformer()
                       .fit(X_train)
                       .transform(X_train))
transformed_X_test = (MapGridTransformer()
                      .fit(X_test)
                      .transform(X_test))

model = pipeline.fit(transformed_X_train[categorical_features + numeric_features], y_train)
y_pred = model.predict(transformed_X_test[categorical_features + numeric_features])
print("Test MSE = %.4f" % mean_squared_error(y_test, y_pred))
# Out:
# Test MSE = 0.2333

# %% [markdown]
# ## Часть 3. Изучаем оставшиеся признаки (1 балл)
#
# **Задание 11 (0.75 баллов)**.
#
# У нас осталось еще 3 признака, которые мы не исследовали: `vendor_id`, `passenger_count` и `store_and_fwd_flag`.
#
# **Вопрос (0.1 балл)**: **(?)** Подумайте, почему каждый из этих признаков может быть потенциально полезным.
#
# **Ответ**
# Думаю, данные записи могут быть полезными, потому что значения этих признаков появляются независимо от предыдущей  плюс явно выделяются категории, которые могут влиять на результат.
# vendor_id возможно поставщик услуг такси может выбирать плохих водителей, которые быстро водят, либо медленно водят из-за ограниченных возможностей машины
# passenger_count допустим с Вами вместе едет еще один человек и этого человека надо подбросить куда-н (при этом это не dropoff) тогда время пути увеличится.
# store_and_fwd_flag сиигнал может пропадать загородом , поэтому время в пути увеличится

# %%
X_train.head(10)
# Out:
#                 id  vendor_id     pickup_datetime  passenger_count  \
# 824746   id2365163          2 2016-03-27 00:25:29                3
# 645821   id3126187          2 2016-03-18 20:44:12                1
# 691846   id2588127          2 2016-04-15 18:26:12                2
# 1147931  id0915715          2 2016-03-24 14:28:34                1
# 183569   id3758776          1 2016-04-28 13:53:52                1
# 121772   id0111855          2 2016-05-09 14:42:03                6
# 40567    id2525305          1 2016-04-09 17:56:39                1
# 650192   id0042030          1 2016-03-29 10:33:54                2
# 119771   id3267762          2 2016-05-14 13:49:53                6
# 494697   id1783695          2 2016-02-01 22:09:17                3
#
#          pickup_longitude  pickup_latitude  dropoff_longitude  \
# 824746         -73.996986        40.742210         -73.987740
# 645821         -73.989929        40.741760         -73.977280
# ...

# %% [markdown]
# **(0.1 балл)** Посчитайте, сколько есть уникальных значений у каждого из этих признаков:

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
print("number of unique els in X_train.vendor_id", X_train.vendor_id.nunique())
print("number of unique els in X_train.passenger_count", X_train.passenger_count.nunique())
print("number of unique els in X_train.store_and_fwd_flag", X_train.store_and_fwd_flag.nunique())
# Out:
# number of unique els in X_train.vendor_id 2
# number of unique els in X_train.passenger_count 9
# number of unique els in X_train.store_and_fwd_flag 2

# %% [markdown]
# **(0.2 балла)** Постройте "ящики с усами" распределений логарифма времени поездки в зависимости от значений каждого из признаков

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
plt.figure(figsize = (13, 5))
a = plt.subplot(131)
sns.boxplot(y=y_train, x=X_train.vendor_id)
a.set_xlabel('Vendor ID')
a.set_ylabel('Log trip time')

a = plt.subplot(132)
sns.boxplot(y=y_train, x=X_train.passenger_count)
a.set_xlabel('Amount of passengers in the car')
a.set_ylabel('Log trip time')

a = plt.subplot(133)
sns.boxplot(y=y_train, x=X_train.store_and_fwd_flag)
a.set_ylabel('Log trip time')
None
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# **(0.2 балла)** Переведите признаки `vendor_id` и `store_and_fwd_flag` в значения $\{0;1\}$

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:
X_train.vendor_id = X_train.vendor_id - 1
X_test.vendor_id = X_test.vendor_id - 1
X_train.store_and_fwd_flag = np.where(X_train['store_and_fwd_flag'] == 'N', 0, 1)
X_test.store_and_fwd_flag = np.where(X_test['store_and_fwd_flag'] == 'N', 0, 1)

# %% [markdown]
# **Вопрос (0.15 балла)**: **(?)** Основываясь на графиках выше, как вы думаете, будут ли эти признаки сильными?

# %% [markdown]
# **Ответ**:
# Нет, так как медианы на одном уровне

# %% [markdown]
# **Задание 12 (0.25 баллов)**. Проверьте свои предположения, обучив модель **в том числе и на этих трех признаках.** Обучайте `Ridge`-регрессию со стандартными параметрами, закодировав  категориальные признаки с помощью `OneHotEncoder`. Численные признаки отмасштабируйте с помощью `StandardScaler`.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
categorical_features = ['dayofweek', 'month', 'hour', 'anomal1',
                        'anomal2', 'traffic_jams', 'empty_roads', 
                        'GuardAirport_pickup', 'GuardAirport_dropoff',
                        'KennedyAirport_pickup', 'KennedyAirport_dropoff',
                        'pickup_idx', 'dropoff_idx', 'vendor_id', 'passenger_count',
                        'store_and_fwd_flag']

numeric_features = ['dayofyear', 'log_haversine']

column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical_features),
    ('scaling', StandardScaler(), numeric_features)
])

pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge())
])

transformed_X_train = (MapGridTransformer()
                       .fit(X_train)
                       .transform(X_train))
transformed_X_test = (MapGridTransformer()
                      .fit(X_test)
                      .transform(X_test))

model = pipeline.fit(transformed_X_train[categorical_features + numeric_features], y_train)
y_pred = model.predict(transformed_X_test[categorical_features + numeric_features])
print("Test MSE = %.4f" % mean_squared_error(y_test, y_pred))
# Out:
# Test MSE = 0.2330

# %% [markdown]
# Если признаки не дали какого-то ощутимого улучшения метрики, их можно выбросить из данных.

# %%
X_train = X_train.drop(['vendor_id', 'passenger_count', 'store_and_fwd_flag'], axis=1)
X_test = X_test.drop(['vendor_id', 'passenger_count', 'store_and_fwd_flag'], axis=1)

# %% [markdown]
# ## Часть 4. Улучшаем модель (3 балла)

# %% [markdown]
# **Задание 13 (1 балл)**.
#
# В наших данных есть нетипичные объекты: с аномально маленьким времени поездки, с очень большим пройденным расстоянием или очень большими остатками регрессии. В этом задании предлагается исключить такие объекты из обучающей выборки.
#
#
# **(0.3 балла)** Для этого нарисуйте гистограммы распределения упомянутых выше величин, выберите объекты, которые можно назвать выбросами, и очистите обучающую выборку от них.
#
# Отметим, что хотя эти объекты и выглядят как выбросы, в тестовой выборке тоже скорее всего будут объекты с такими же странными значениями целевой переменной и/или признаков. Поэтому, возможно, чистка обучающей выборки приведёт к ухудшению качества на тесте. Тем не менее, всё равно лучше удалять выбросы из обучения, чтобы модель получалась более разумной и интерпретируемой.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
quant = np.quantile(y_train, 0.01)
plot = sns.displot(y_train[y_train >= quant])
plot.ax.set_xlim()
print(X_train.shape, y_train.shape)
None
# Out:
# (1021050, 23) (1021050,)

# %%
X_train = X_train.drop(y_train[y_train < quant].index)
y_train = y_train.drop(y_train[y_train < quant].index)
print(X_train.shape, y_train.shape)
# Out:
# (1011021, 23) (1011021,)

# %%
X_train.columns
# Out:
# Index(['id', 'pickup_datetime', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'pickup_hour', 'pickup_month',
#        'pickup_dayofweek', 'dayofweek', 'month', 'hour', 'anomal1', 'anomal2',
#        'dayofyear', 'haversine', 'log_haversine', 'traffic_jams',
#        'empty_roads', 'GuardAirport_pickup', 'GuardAirport_dropoff',
#        'KennedyAirport_pickup', 'KennedyAirport_dropoff'],
#       dtype='object')

# %%
quant = np.quantile(X_train.log_haversine, 0.99)
sns.displot(X_train.log_haversine[X_train.log_haversine < quant])

# %%
y_train = y_train.drop(y_train[X_train.log_haversine >= quant].index)
X_train = X_train.drop(X_train[X_train.log_haversine >= quant].index)

# %%
categorical_features = ['dayofweek', 'month', 'hour', 'anomal1',
                        'anomal2', 'traffic_jams', 'empty_roads', 
                        'GuardAirport_pickup', 'GuardAirport_dropoff',
                        'KennedyAirport_pickup', 'KennedyAirport_dropoff',
                        'pickup_idx', 'dropoff_idx']

numeric_features = ['dayofyear', 'log_haversine']

column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical_features),
    ('scaling', StandardScaler(), numeric_features)
])

pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge())
])

transformed_X_train = (MapGridTransformer()
                       .fit(X_train)
                       .transform(X_train))


model = pipeline.fit(transformed_X_train[categorical_features + numeric_features], y_train)
y_pred = model.predict(transformed_X_train[categorical_features + numeric_features])
print("Test MSE = %.4f" % mean_squared_error(y_train, y_pred))
# Out:
# Test MSE = 0.1992

# %%
regression_residuals = np.abs(np.expm1(y_pred) - np.expm1(y_train))
quant = np.quantile(regression_residuals, 0.99)
g = sns.displot(regression_residuals[regression_residuals < quant])
g.ax.set_xlabel('regression_residuals')
y_train = y_train.drop(X_train[regression_residuals >= quant].index)
X_train = X_train.drop(X_train[regression_residuals >= quant].index)
None

# %% [markdown]
# **(0.3 балла)** Сейчас у нас очень много категориальных признаков. В категориальных признаках могут содержаться редкие категории, обычно это плохо: модель сильно переобучается на таких примерах. Попробуйте объединить редкие категории в одну. Естественно, делать это нужно только для действительно редких категорий.

# %%
X_train.columns
# Out:
# Index(['id', 'pickup_datetime', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'pickup_hour', 'pickup_month',
#        'pickup_dayofweek', 'dayofweek', 'month', 'hour', 'anomal1', 'anomal2',
#        'dayofyear', 'haversine', 'log_haversine', 'traffic_jams',
#        'empty_roads', 'GuardAirport_pickup', 'GuardAirport_dropoff',
#        'KennedyAirport_pickup', 'KennedyAirport_dropoff'],
#       dtype='object')

# %%
X_train = X_train.drop(['pickup_hour', 'pickup_month', 'pickup_dayofweek'], axis=1)
X_test= X_test.drop(['pickup_hour', 'pickup_month', 'pickup_dayofweek'], axis=1)

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
plt.figure(figsize=(10,5))
ax = sns.countplot(x=X_train.hour)
ax.set_xlabel("Pickup hour", fontsize=20)
ax.set_ylabel("Counts",fontsize=20)
ax.tick_params(labelsize=14)

# %%
#объединим 5 и 4
X_train.loc[X_train.hour == 4, 'hour'] = 5

# %% [markdown]
# **(0.4 балла)**Обучите модель на очищенных данных и посчитайте качество на тестовой выборке.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
categorical_features = ['dayofweek', 'month', 'hour', 'anomal1',
                        'anomal2', 'traffic_jams', 'empty_roads', 
                        'GuardAirport_pickup', 'GuardAirport_dropoff',
                        'KennedyAirport_pickup', 'KennedyAirport_dropoff',
                        'pickup_idx', 'dropoff_idx']

numeric_features = ['dayofyear', 'log_haversine']

column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical_features),
    ('scaling', StandardScaler(), numeric_features)
])

pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge())
])

transformed_X_train = (MapGridTransformer()
                       .fit(X_train)
                       .transform(X_train))
transformed_X_test = (MapGridTransformer()
                      .fit(X_test)
                      .transform(X_test))

ridge_pipeline = pipeline.fit(transformed_X_train[categorical_features + numeric_features], y_train)
y_pred = ridge_pipeline.predict(transformed_X_test[categorical_features + numeric_features])
print("Test MSE = %.4f" % mean_squared_error(y_test, y_pred))
# Out:
# Test MSE = 0.2340

# %% [markdown]
# **Задание 14 (1 балл)**.
#
# **(0.1 балл)** После OneHot-кодирования количество признаков в нашем датасете сильно возрастает. Посчитайте колиество признаков до и после кодирования категориальных признаков.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
transformed_X_train = (MapGridTransformer()
                       .fit(X_train)
                       .transform(X_train))
print("Size before OneHot:", transformed_X_train.shape)
print("Size after OneHot:", column_transformer.transform(transformed_X_train).shape)
# Out:
# Size before OneHot: (990900, 22)
# Size after OneHot: (990900, 92)

# %% [markdown]
# **(0.2 балла)** Попробуйте обучить не `Ridge`-, а `Lasso`-регрессию. **(?)** Какой метод лучше?

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:
from sklearn.linear_model import Lasso
categorical_features = ['dayofweek', 'month', 'hour', 'anomal1',
                        'anomal2', 'traffic_jams', 'empty_roads', 
                        'GuardAirport_pickup', 'GuardAirport_dropoff',
                        'KennedyAirport_pickup', 'KennedyAirport_dropoff',
                        'pickup_idx', 'dropoff_idx']

numeric_features = ['dayofyear', 'log_haversine']

column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical_features),
    ('scaling', StandardScaler(), numeric_features)
])

pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Lasso())
])

transformed_X_train = (MapGridTransformer()
                       .fit(X_train)
                       .transform(X_train))
transformed_X_test = (MapGridTransformer()
                      .fit(X_test)
                      .transform(X_test))

lasso_pipeline = pipeline.fit(transformed_X_train[categorical_features + numeric_features], y_train)
y_pred = lasso_pipeline.predict(transformed_X_test[categorical_features + numeric_features])
print("Test MSE = %.4f" % mean_squared_error(y_test, y_pred))
# Out:
# Test MSE = 0.6309

# %% [markdown]
# **Отвеn**:
# Намного лучше скор с L2 регуляризацией

# %% [markdown]
# **(0.5 балла)** Разбейте обучающую выборку на обучающую и валидационную в отношении 8:2. По валидационной выборке подберите оптимальные значения параметра регуляризации (по логарифмической сетке) отдельно для `Ridge` и отдельно для `Lasso`, на тестовой выборке измерьте качество лучшей полученной модели.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
X_subtrain, X_val, y_subtrain, y_val = train_test_split(X_train, y_train, 
                                                        train_size=0.8,
                                                        random_state=3)

# %%
from sklearn.model_selection import GridSearchCV
am = 50
alphas = np.logspace(-2, 3, am)
# cv будет разбивать на валидационную и обучающую
mse_r = np.empty(am)
for idx, alpha in enumerate(alphas):
    column_transformer = ColumnTransformer([
        ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical_features),
        ('scaling', StandardScaler(), numeric_features)
    ])

    pipeline = Pipeline(steps=[
        ('ohe_and_scaling', column_transformer),
        ('regression', Ridge(alpha))
    ])

    transformed_X_train = (MapGridTransformer()
                        .fit(X_subtrain)
                        .transform(X_subtrain))
    
    transformed_X_test = (MapGridTransformer()
                        .fit(X_val)
                        .transform(X_val))

    ridge_pipeline = pipeline.fit(
        transformed_X_train[categorical_features + numeric_features], y_subtrain)
    y_pred = ridge_pipeline.predict(
        transformed_X_test[categorical_features + numeric_features])
    
    mse_r[idx] = mean_squared_error(y_val, y_pred)

# %%
print("Best alpha Ridge = %.4f" % alphas[np.argmin(mse_r)])
print("Best MSE Ridge = %.4f" % np.min(mse_r))
# Out:
# Best alpha Ridge = 0.0829
# Best MSE Ridge = 0.1571

# %%
from sklearn.model_selection import GridSearchCV
am = 20
alphas = np.logspace(-4, 4, am)
# cv будет разбивать на валидационную и обучающую
mse_l = np.empty(am)
lasso_zeroes = np.empty(am)
for idx, alpha in enumerate(alphas):
    column_transformer = ColumnTransformer([
        ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical_features),
        ('scaling', StandardScaler(), numeric_features)
    ])

    pipeline = Pipeline(steps=[
        ('ohe_and_scaling', column_transformer),
        ('regression', Lasso(alpha))
    ])

    transformed_X_train = (MapGridTransformer()
                        .fit(X_subtrain)
                        .transform(X_subtrain))
    
    transformed_X_test = (MapGridTransformer()
                        .fit(X_val)
                        .transform(X_val))

    lasso_pipeline = pipeline.fit(
        transformed_X_train[categorical_features + numeric_features], y_subtrain)
    y_pred = lasso_pipeline.predict(
        transformed_X_test[categorical_features + numeric_features])
    
    lasso_zeroes[idx] = np.sum(lasso_pipeline.steps[-1][-1].coef_ == 0)
    mse_l[idx] = mean_squared_error(y_val, y_pred)


print("Best alpha Lasso = %.4f" % alphas[np.argmin(mse_l)])
print("Best MSE Lasso = %.4f" % np.min(mse_l))
# Out:
# Best alpha Lasso = 0.0001
# Best MSE Lasso = 0.1571

# %%
categorical_features = ['dayofweek', 'month', 'hour', 'anomal1',
                        'anomal2', 'traffic_jams', 'empty_roads', 
                        'GuardAirport_pickup', 'GuardAirport_dropoff',
                        'KennedyAirport_pickup', 'KennedyAirport_dropoff',
                        'pickup_idx', 'dropoff_idx']

numeric_features = ['dayofyear', 'log_haversine']

column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical_features),
    ('scaling', StandardScaler(), numeric_features)
])

pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge(0.0829))
])

transformed_X_train = (MapGridTransformer()
                       .fit(X_train)
                       .transform(X_train))
transformed_X_test = (MapGridTransformer()
                      .fit(X_test)
                      .transform(X_test))

lasso_pipeline = pipeline.fit(
    transformed_X_train[categorical_features + numeric_features], y_train)
y_pred = lasso_pipeline.predict(
    transformed_X_test[categorical_features + numeric_features])
print("Test MSE = %.4f" % mean_squared_error(y_test, y_pred))
# Out:
# Test MSE = 0.2340

# %% [markdown]
# **(0.2 балла)** Для каждого перебранного `alpha` для Lasso посчитайте количество нулевых весов в модели и нарисуйте график зависимости его от `alpha`. **(?)** Как сильно придётся потерять в качестве, если мы хотим с помощью Lasso избавиться хотя бы от половины признаков?

# %%
plt.figure(figsize=(10, 5))
a = plt.subplot(121)
plt.xscale("log")
plt.plot(alphas, mse_l)
plt.xlabel("alpha")
plt.ylabel("score")
a = plt.subplot(122)
plt.xscale("log")
plt.plot(alphas, lasso_zeroes)
plt.xlabel("alpha")
plt.ylabel('amount of zero-weights')
None

# %% [markdown]
# если с помощью лассо избавиться от половину признаков, то качество алгоритма упадет примерно на 0.1 mse_score. Что довольно много.

# %% [markdown]
# <img src="https://www.dropbox.com/s/wp4jj0599np17lh/map_direction.png?raw=1" width="20%" align="right" style="margin-left: 20px">
#
# **Задание 15 (1 балл + 1 бонус)**.
#
# **(0.7 баллов)** Часто бывает полезным использовать взаимодействия признаков (feature interactions), то есть строить новые признаки на основе уже существующих. Выше мы разбили карту Манхэттена на ячейки и придумали признаки "из какой ячейки началась поездка" и "в какой ячейке закончилась поездка".
#
# Давайте попробуем сделать следующее: посчитаем, сколько раз встречается каждая возможная пара этих признаков в нашем датасете и выберем 100 самых частых пар. Закодируем поездки с этими частыми парами как категориальный признак, остальным объектам припишем -1. Получается, что мы закодировали, откуда и куда должно было ехать такси.
#
# Также можете придумать ещё какой-нибудь способ сделать признаки про маршрут. Если эти признаки будут давать хороший прирост в качестве, то за это могут быть даны дополнительные бонусные баллы **(до 1 бонусного балла)**

# %%
X_train.shape
# Out:
# (990900, 20)

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
X_train = MapGridTransformer().fit(X_train).transform(X_train)
X_test = MapGridTransformer().fit(X_train).transform(X_test)
X_train.shape
# Out:
# (990900, 22)

# %%
pairs_pick_drop_order = X_train.groupby(['pickup_idx', 'dropoff_idx']).size()
pairs_pick_drop_order = pairs_pick_drop_order.sort_values(ascending=False)[:100]
index_coo_together = X_train[['pickup_idx', 'dropoff_idx']].apply(tuple, axis=1)
X_train['coo_pairs_ordered'] = -1
for  i in range(100):
    mask = index_coo_together.isin([pairs_pick_drop_order.index[i]])
    X_train.loc[mask.to_numpy(), 'coo_pairs_ordered'] =  i

# %%
pairs_pick_drop_order = X_test.groupby(['pickup_idx', 'dropoff_idx']).size()
pairs_pick_drop_order = pairs_pick_drop_order.sort_values(ascending=False)[:100]
index_coo_together = X_test[['pickup_idx', 'dropoff_idx']].apply(tuple, axis=1)
X_test['coo_pairs_ordered'] = -1
for  i in range(100):
    mask = index_coo_together.isin([pairs_pick_drop_order.index[i]])
    X_test.loc[mask.to_numpy(), 'coo_pairs_ordered'] =  i

# %% [markdown]
# **Вопрос (0.2 балла)**: **(?)** Почему такой признак потенциально полезный? Почему линейная модель не может самостоятельно "вытащить" эту информацию, ведь у нее в распоряжении есть признаки "из какой ячейки началась поездка" и "в какой ячейке закончилась поездка"?

# %% [markdown]
# **Ответ**:
# Данный признак может быть полезен, поскольку он задает вектор популярности маршрутов( см вектор в условии). до этого в модели это не учитывалось поскольку, маршрутов больше из $A$ в  $∀$ $C$ чем из $A$ в конкретную $B$, то есть направление уже не учитывается.

# %% [markdown]
# **(0.1 балл)** Заново обучите модель (`Ridge`, если она дала более высокое качество в предыдущих экспериментах, и `Lasso` иначе) на новых даннных и посчитайте качество на тестовой выборке

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
categorical_features = ['dayofweek', 'month', 'hour', 'anomal1',
                        'anomal2', 'traffic_jams', 'empty_roads', 
                        'GuardAirport_pickup', 'GuardAirport_dropoff',
                        'KennedyAirport_pickup', 'KennedyAirport_dropoff',
                        'pickup_idx', 'dropoff_idx', 'coo_pairs_ordered']

numeric_features = ['dayofyear', 'log_haversine']

column_transformer = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown="ignore"), categorical_features),
    ('scaling', StandardScaler(), numeric_features)
])

pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Ridge(0.0829))
])



ridge_pipeline = pipeline.fit(
    X_train[categorical_features + numeric_features], y_train)
y_pred = ridge_pipeline.predict(
    X_test[categorical_features + numeric_features])
print("Test MSE = %.4f" % mean_squared_error(y_test, y_pred))
# Out:
# Test MSE = 0.2389

# %%
categorical_features = ['dayofweek', 'month', 'hour', 'anomal1',
                        'anomal2', 'traffic_jams', 'empty_roads', 
                        'GuardAirport_pickup', 'GuardAirport_dropoff',
                        'KennedyAirport_pickup', 'KennedyAirport_dropoff',
                        'pickup_idx', 'dropoff_idx', 'coo_pairs_ordered']

numeric_features = ['dayofyear', 'log_haversine']
X_test[categorical_features + numeric_features]
# Out:
#         dayofweek  month  hour  anomal1  anomal2  traffic_jams  empty_roads  \
# 112342          5      1     0     True    False         False        False
# 840803          2      2    19    False    False         False        False
# 184538          3      5     6    False    False         False        False
# 512001          3      1     8    False    False         False        False
# 776055          5      1    13    False    False          True        False
# ...           ...    ...   ...      ...      ...           ...          ...
# 846197          5      1    23    False    False         False        False
# 85559           3      6    15    False    False         False        False
# 940126          0      5     9    False    False          True        False
# 643278          2      4     9    False    False          True        False
# 151807          3      3    16    False    False         False        False
#
# ...

# %% [markdown]
# **Задание 16 (бонус, 1 балл)**. Где, как не для нашей задачи, считать манхэттенское расстояние?
#
# **Вопрос (0.2 балла)**: **(?)** Найдите, что такое манхэттенское расстояние и почему оно так называется. Как оно нам может помочь?
#
# **Ответ**:
# ВАШ ОТВЕТ ЗДЕСЬ

# %% [markdown]
# **(0.5 балла)** Введите систему координат на нашей карте так, чтобы оси были параллельны улицам Манхэттена, и добавьте сначала в данные признак "манхэттенское расстояние между пунктом отправления и пунктом назначения", а затем и логарифм этого признака. Посчитайте корреляцию между вашим новыми признаком и таргетом; между `log_haversine` и таргетом. В каком случае корреляция больше?
#
# Нарисуйте карту, где покажете выбранные оси. Чтобы мы могли проверить вашу работу, просьба сделать скрин этой карты и приложить картинку (если мы откроем ваш ноутбук, виджеты отображаться не будут).

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ

# %% [markdown]
# **(0.3 балла)** Заново обучите модель на новых даннных и посчитайте качество на тестовой выборке. **(?)** Стало ли лучше? Объясните полученный результат.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ

# %% [markdown]
# **Задание 17 (бонус, 2 балла)**. Реализуйте трансформер, который строит разбиение карты по шестигранной решётке с помощью библиотеки [H3](https://github.com/uber/h3-py) и вычисляет признаки на основе такого разбиения.
#
# Признаки могут быть самые разные: расстояние между точкой старта и финиша, посчитанное в количестве шестиугольников; статистика по числу поездок и по их продолжительности в соседних шестиугольниках.
#
# Важно: производительность библиотеки существенно зависит от количества шестиугольников на карте (определяется параметром resolution). Подберите такое разрешение, при котором ваш код будет работать за приемлемое время.
#
# При построении признаков старайтесь не допустить утечки целевой переменной --- в противном случае хорошего качества на тестовой выборке достичь не получится.
#
# Измерьте качество после добавления новых признаков. За улучшение функционала ошибки на каждые 0.005 на тестовой выборке будет даваться 0.5 бонусных балла. Можно получить до 2 бонусных баллов за это задание.

# %%
#╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ

# %% [markdown]
# **Бонус (0.3 балла)** Вставьте картинку, описывающую ваш опыт выполнения этого ДЗ.

# %% [markdown]
# ![0*ti1EtGzf0erzXVbG.jpeg](data:image/jpeg;base64,...)
